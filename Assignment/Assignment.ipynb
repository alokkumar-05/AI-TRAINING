# %%
from transformers import pipeline

# %% [markdown]
# # Question 1
#
# ## Scenario
#
# You are developing a movie review analysis tool for a streaming platform. The platform wants to automatically classify user reviews as positive or negative using Hugging Face.
#
# ## Questions
#
# 1. Which Hugging Face pipeline would you use?
# 2. What output do you expect?
# 3. Why is the `pipeline()` abstraction useful for beginners compared to manually loading models and tokenizers?

# %%
#Sentiment Analysis Application

model = "cardiffnlp/twitter-xlm-roberta-base-sentiment"
text = "Movie story was disappointing"

classifier = pipeline("sentiment-analysis", model=model)
response = classifier(text)
print(response)
# Out:
# config.json:   0%|          | 0.00/841 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# pytorch_model.bin: reconstructing file:   0%|          |  0.00B / 1.11GB
# pytorch_model.bin: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 1.11GB
# model.safetensors: downloading bytes:           |  0.00B
# sentencepiece.bpe.model: reconstructing file:   0%|          |  0.00B / 5.07MB
# sentencepiece.bpe.model: downloading bytes:           |  0.00B
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# [{'label': 'negative', 'score': 0.956287682056427}]

# %% [markdown]
# # Question 2
#
# ## Scenario
#
# A multinational company receives customer feedback in **English, Hindi, and Spanish**. The default `sentiment-analysis` model is giving poor results for non-English reviews.
#
# You discover the Hugging Face model:
#
# `tabularisai/multilingual-sentiment-analysis`
#
# ## Questions
#
# 1. Why would this model be more suitable than the default sentiment analysis pipeline?
# 2. Write the steps required to load and use this model.
# 3. What factors would you consider before deploying it in production (e.g., accuracy, latency, model size, language support)?

# %%
#customer feedback
model = "tabularisai/multilingual-sentiment-analysis"
classifier= pipeline("sentiment-analysis" , model = model)

text = [
    "The product is amazing!",
    "यह उत्पाद बहुत अच्छा है।",
    "Este producto es excelente."
]

response = classifier(text)
print(response)
# Out:
# model.safetensors: reconstructing file:   0%|          |  0.00B /  541MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# [{'label': 'Very Positive', 'score': 0.5125332474708557}, {'label': 'Positive', 'score': 0.8585635423660278}, {'label': 'Positive', 'score': 0.7853776812553406}]

# %% [markdown]
# # Question 3
#
# ## Scenario
#
# You are building an AI-powered educational assistant that generates explanations for engineering concepts.
#
# Initially, you used:
#
# ```python
# pipeline("text-generation", model="Qwen/Qwen2.5-7B-Instruct")
# ```
#
# However, your team now requires:
#
# - Full control over tokenization
# - Custom prompt formatting
# - Access to model inputs and outputs
# - Optimization for deployment
#
# ## Questions
#
# 1. Explain why the team should move from the `pipeline()` approach to the manual workflow using:
#    - `AutoTokenizer`
#    - `AutoModelForCausalLM`
# 2. Compare the architecture of the Pipeline API and Manual Workflow.
# 3. Explain the role of tokenization and token IDs in text generation.
# 4. Describe how the text **"Explain Linear Regression"** flows through the tokenizer and model before the final output is generated.
# 5. Discuss the trade-offs between ease of use and flexibility.

# %%
#AI-powered educational assistant

from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "Qwen/Qwen2.5-7B-Instruct"

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Load model
model = AutoModelForCausalLM.from_pretrained(model_name)

# Input text
text = "Explain Linear Regression"

# Convert text into token IDs
inputs = tokenizer(text, return_tensors="pt")

# Generate output token IDs
outputs = model.generate(**inputs, max_new_tokens=100)

# Decode output IDs into text
response = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(response)
# Out:
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/27.8k [00:00<?, ?B/s]
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# ...
# Loading weights:   0%|          | 0/339 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
